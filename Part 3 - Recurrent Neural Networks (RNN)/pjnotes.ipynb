# %% [markdown]
# # Recurrent Neural Networks(RNNs)

# %% [markdown]
# # Plan of attack:
# 1. The idea behind RNNs
# 2. The vanishing gradient problems
# 3. Long Short-Term Memory(LSTM)
# 4. Practical Intuition
# 5. Extra info on LSTM variations

# %% [markdown]
# weights ---> long term memory so in `Temporal lobe` --->`ANNs`<br>
# `CNNs`---> vision related ---> `occipital lobe`<br>
# `Frontal lobe` --> short term memory ---> `RNNs`<br>
# There is no neural network yet that can function as `Parietal Lobe` which perception and making corelations with other neurons.
# ![Screenshot%20from%202018-08-12%2015-07-17.png](Screenshot from 2018-08-12 15-07-17.png)

# %% [markdown]
# To convert a ANN into RNN we sqash it into one.<br>
# whole network is still there but the network is flattened out.<br>
# change the multiple arrows in to just 2 and then make it vertical(for convention).hidden layer is blue and now there is one more arrow form blue to itself.<br>
# <p>
#
# This new line is representation of `temporal loop`.i.e. the hiddenlayer along with giving output, feeds back the results into itself. This gives the network some kind of artificial short term memory.<br>
#
# ![Screenshot%20from%202018-08-12%2015-07-21.png](Screenshot%20from%202018-08-12%2015-07-21.png)![Screenshot%20from%202018-08-12%2015-07-23.png](Screenshot%20from%202018-08-12%2015-07-23.png)![Screenshot%20from%202018-08-12%2015-07-46.png](Screenshot%20from%202018-08-12%2015-07-46.png)![Screenshot%20from%202018-08-12%2015-07-31.png](Screenshot%20from%202018-08-12%2015-07-31.png)
#
# <p>
#
#
# After unwinding and making networks they look like this:
# <br>
#
# ![Screenshot%20from%202018-08-12%2015-07-56.png](Screenshot%20from%202018-08-12%2015-07-56.png)
# Again actual network looks complex:
# so each one is not one neuron but the layer of neurons.<br>
# ![Screenshot%20from%202018-08-12%2015-07-49.png](Screenshot%20from%202018-08-12%2015-07-49.png)
# <p>
#
# Example 1. describing pictures: Part 1 the CNN first of all recognises things in picture and puts it to Long term memory ie. works on the weights. Now when the RNN is used for the short term memory to make a sentence to describe a picture. `Example of one to many`
# <p>
#
# Example 2: `Many to one` is used for example to do sentiment analysis.<br>
#
# <p>
#
# Example 3: translation, works with the RNNs as some languages the previous words determine the structure of the sentences further down the line where short term memory becomes very important. `Many to many`<br>
# <p>
#
#
# Example 4: The `many to many` RNNs can be used to give the subtitles to the movies. As for this task we need the short term context.
# <p>
#
#
# ![Screenshot%20from%202018-08-12%2015-09-12.png](Screenshot%20from%202018-08-12%2015-09-12.png)

# %% [markdown]
# ### Vanishing Gradient

# %% [markdown]
# In RNNs information from from previous time keeps coming to the nodes. Every time we calculate the cost using cost function. It basically compares your output which is in the right circle to your desired output. To update the weights, for every neuron the error has to be propagated, Wrec when passed back on multiplying by small number gradient goes on decreasing(hence the vanishing gradient.) As gradient is used to update the weights, the smaller the gradient gets, it becomes harder to update weights(slower to update to be more accurate). The problem is that the training is done at the higher gradients but at farther point the neurons are not trained properly and hence the network is not being trained properly.<p>
#
# ![Screenshot%20from%202018-08-12%2018-16-56.png](Screenshot%20from%202018-08-12%2018-16-56.png)
#
# Wrec--->small ---> Vanishing gradient problem<br>
# Wrec---> Large---> Exploding gradient problem<br>
# <p>
# Solutions:
# for exploding:
# truncated backpropagation, penalties,gradient clipping
# <p>
#
# for vanishing: weight initialization, echo state networks, Long short term memory networks(LSTMs)
# ![Screenshot%20from%202018-08-12%2018-17-18.png](Screenshot%20from%202018-08-12%2018-17-18.png)

# %% [markdown]
# ### Long Short-Term Memory

# %% [markdown]
# ![Screenshot%20from%202018-08-12%2018-52-14.png](Screenshot%20from%202018-08-12%2018-52-14.png)
#
#
# There is a memory cell or memory pipeline which runs through the RNN.<br>
#
# `C` is for memory<br>
# `h` is for output<br>
# `X` is input<br>
# All of these represent the layers.<br>
# <p>
#
# Hence 3 inputs and 2 outputs.<br>
# `x`s are valves, forget valve, memory valve and output valve.<br>
# every valve is controlled by the `sigma`s which are the `activation functions`<br>
# `+`s are T-shaped joints.<br>
#
# the `sigmas` and `tanh`s are neural network operations<br>
# ![Screenshot%20from%202018-08-12%2018-53-11.png](Screenshot%20from%202018-08-12%2018-53-11.png)
# <p>
#
# <b>Step by Step break down:</b>
# ![Screenshot%20from%202018-08-12%2018-53-30.png](Screenshot%20from%202018-08-12%2018-53-30.png)![Screenshot%20from%202018-08-12%2018-53-27.png](Screenshot%20from%202018-08-12%2018-53-27.png)![Screenshot%20from%202018-08-12%2018-53-24.png](attachment:Screenshot%20from%202018-08-12%2018-53-24.png)![Screenshot%20from%202018-08-12%2018-53-21.png](Screenshot%20from%202018-08-12%2018-53-21.png)
#
#
#
# ![Screenshot%20from%202018-08-12%2018-53-51.png](Screenshot%20from%202018-08-12%2018-53-51.png)![Screenshot%20from%202018-08-12%2018-53-46.png](Screenshot%20from%202018-08-12%2018-53-46.png)![Screenshot%20from%202018-08-12%2018-53-49.png](Screenshot%20from%202018-08-12%2018-53-49.png)![Screenshot%20from%202018-08-12%2018-53-38.png](Screenshot%20from%202018-08-12%2018-53-38.png)

# %% [markdown]
# ### Practical workings of LSTMs

# %% [markdown]
# About the `tanh` functions `-1(red) +1(blue)`<br>
# Example of `novel reading` as it can detect the `end of line` and `inside and outside` of the quotes.<br>
# <p>
#
# `c code` review to find the if statements and also the level of the iteration.<br>
# <p>
#
#
# another `c code` review<br><p>
#
# Example of RNN trying to read and predict what hyou
# The neural network is predicting what is going to come next(`green` is active `blue` is non active shades of `red` are predictions dark being `more likely` and light beig `less likely`)<br>
#
#
# ![Screenshot%20from%202018-08-12%2019-30-09.png](Screenshot%20from%202018-08-12%2019-30-09.png)![Screenshot%20from%202018-08-12%2019-29-49.png](Screenshot%20from%202018-08-12%2019-29-49.png)![Screenshot%20from%202018-08-12%2019-30-21.png](Screenshot%20from%202018-08-12%2019-30-21.png)![Screenshot%20from%202018-08-12%2019-30-24.png](Screenshot%20from%202018-08-12%2019-30-24.png)![Screenshot%20from%202018-08-12%2019-29-54.png](Screenshot%20from%202018-08-12%2019-29-54.png)![Screenshot%20from%202018-08-12%2019-30-01.png](Screenshot%20from%202018-08-12%2019-30-01.png)

# %% [markdown]
# ### LSTM variations

# %% [markdown]
# peekholes:
#
# combined decision for memory valve and forget valve:
#
# Gated recurring units(GRUs):
#
#
#
# ![Screenshot%20from%202018-08-12%2019-43-08.png](Screenshot%20from%202018-08-12%2019-43-08.png)![Screenshot%20from%202018-08-12%2019-42-58.png](Screenshot%20from%202018-08-12%2019-42-58.png)![Screenshot%20from%202018-08-12%2019-41-36.png](Screenshot%20from%202018-08-12%2019-41-36.png)![Screenshot%20from%202018-08-12%2019-41-33.png](Screenshot%20from%202018-08-12%2019-41-33.png)![Screenshot%20from%202018-08-12%2019-42-22.png](Screenshot%20from%202018-08-12%2019-42-22.png)

# %% [markdown]
# ### Brownian motion
# States that the future evaluations of the stock price are independent from the past.<br>
# It's actually impossible to predict future prices of the stocks, but it is possible to predict the trends.<br>
# Lets build  `LSTM model to predict the downward and upward trend of the Google stock price`.<br>
# The LSTM is going to be robust with high dimentionality, several layers. `Drop out regularization` will be made to avoid overfitting.
# <br>
# The model will be trained on the five years of google stock prices. 2012-2016---> prediction will be for the first month of 2017. <br>
#
# <p>
#
# `Google_Stock_Price_Train` has the data and we will predict the stock price on `Open` day i.e stock price at beginning of the financial day.<br>
# <br>
# `Google_Stock_Price_Test` has the open stock prices in 2017 and hence the model will try to predict the trend.<br>
# <br>
#
# To implement we will do:<br>
# 1. Data preprocessing <br>
# 2. Build the RNN<br>
# 3. Make the predictions<br>

# %% [markdown]
# ### Data preprocessing:
# Import libraries, import training set---> DataFrame---> select the right columns and make `numpy array` as these can only be input for the neural networks(use .values on df to make it numpy array).<br>
# `Feature scaling` Standarization, Normalization here we use Normalization(MinMaxScaler will do the job) as the activation function is going to be sigmoid function.<br>
#
# <p>
#
# `Number of time steps`
# <br> Datastructure specifying what RNN will have to remember for prediction of next stock prices.<br>
# ---> very important as wrong number of time steps could lead to overfitting or nonsense predictions.<br>
#
# `60 time steps and 1 output`---> at each time t, RNN is going to look at 60 stock prices before time t, and based on the correlations that it finds it will try to predict next output.<br>
# `if 1 time step and 1 output it will overfit, 60 here is selected by experimentation.`<br>
# hence 60 time steps ---> 60 financial days---> 20 in a month---> 3 months worth of data is used to predict the output.<br>
#
# <p>
#
# 2 entities---> X_train---> input for RNN, y_train ---> output for the RNN.<br>
# X_train will be 1st 60 data, y_train willbe 61st data.<br>
#
# make X_train and y_train a numpy array.<br>
#
# `Adding new dimentionality to the data structures` to
# make predictions more powerful i.e. including the other features apart from open prices in the beginning of the day to predict the stock prices.<br>
# `Reshape function` will do the job.<br>
#
# <p>
#
# `keras library---> Recurrent layers` section will give information about the input shapes.<br>
# and according to it the shape should be `(batch_size,timesteps,input_dim)` so lets reshape X_train to ()<br>
# batch_size-->number of entries---> X_train.shape[0]<br>
# timesteps---> number of columns--->X_train.shape[1]<br>
# input_dim--->number of indicators, number of predictors here is only 1(open google stock price).<br>
#
# <p>
#
# ### Build a RNN:
#
# `Sequential` class to  create neural network object<br>
# `Dense` class to add output layer<br>
# `LSTM` class to add LSTM layers<br>
# `Dropout`class to add dropout regularization to prevent overfitting.<br>
# <p>
#
# `Initializing RNN layers` using pytorch<br>
# `regressor`---> is initialized (prediction of `continuous` class)<br>
# <br>
# add:<br>
# `LSTM` layer----> parameters:<br>
# `units`---> number of LSTMs or Memory units(neurons)--->for model of high dimentionality we choose 50 here to capture the trends in stock prices as it is a pretty complex task to do<br>
# `return_sequences`---> `True` cuz we are going to add another LSTM after this for the stacked LSTM neural networks. For the last LSTM it is `False`(since the default value is False if you leave it for the last LSTM layer it will pick it up)<br>
# `input_shape`---> contains the last two dimentions corresponding to timesteps and indicators.<br>
# <br><br>
# `for Dropout`:<br>
# `Dropout layer`---> Number of neurons to ignore while training so avoid overfitting---> giving the dropout rate(`drop 20%` here).<br>
# parameters:<br>
# dropout rate--->0.2<br>
# <p>
#
# `More LSTMs`---> don't specify the input_shape(it picks up)  and for each some `Dropout` regularization.<br>
#
# <p>
#
#
# `Adding output layer---> Dense(fully connected layer)`---> parameters:<br>
# units---> number of neurons--->dimention of output the output layer, here it is `1`.<br>
# <p>
#
#
# `compiling the RNN`---> parameters: <br>
# `optimizer`for RNN--->`RMSprop` is used here we will use `adam`<br>
# `loss` regression--->`MSE`--->'mean_squared_error'<br>
# <p>
#
# `Fitting RNN`:<br>
# `epochs`--->number of iterations we want our NN to be trained on. i.e. number of times the whole data has to be forward propagated and then backward propagated before the training of weights is done.Here `100` experimented with 25,50,75 to see less convergence or no convergence of loss.<br>
# `batch size`---> rather than sending every single observation to train the network on, we send the data in batches---> collection of `32` here for example.<br>
#
# ### Making predictions and visualizations:
# get the test set as df and then change it to numpy array.<br>
# The `test price` will be the real values of the stock prices<br>
# we get the `predicted price` <br>
# then we will visualize them separately.<br>
# `test price---> Real values of stock prices` are loaded from test csv file directly. <br>
# <p>
#
# `For getting predicted price`:<br>
# To get the price at every day, 60 values before it will be needed.<br>
# To get this for every day of january, we will need values from both `training set and test set`.<br>
# Hence the `concated` form of the training set and test set has to be formed.<br>
# <p>
#
#
# To avoid the changing of values for Test set(which will be the case if we directly concat the scaled training set and real values from test set---> which will have to be scaled to make it possible as training set is scaled), we will concat the DataFrames(non scaled ones)---> give the inputs for each prediction. And this will be something that we will scale(for the prediction on the model which was trained on scaled input with same scaling object.)<br>
#
# <p>
#
# `concat` the `Open` columns on `axis 0`<br>
# `get inputs---> 60 previous values`---> `reshape(-1,1)` reshape the numpy array into one column.<br>
# `scale the input before predicting`---> scale the inputs not the test values. just using `transform` as there is no need to fit again.<br>
# <p>
#
#
# `creating the special 3d structure, expected by predict method.`:<br>
#
# `X_test` for the whole test data ie. 0 to 80 in 60 intervals for values beween 60 and 80 using 60 values for each prediction from `inputs`.<br>
# `convert to the np.array`<br>
# `convert to 3d array` using reshape with as we did for `X_train`.<br>
# `predicted_stock_price` using predict method.<br>
# `inverse the scaling`--->using `inverse_transform` on scaling object.<br>
# <p>
#
#
# `visualise the stock prices real and predicted`<br>
#
# <p>
#
# `Analysis`:<br>
#
# some parts predictions lag behind actual values as our model can't react to fast changing non linear real values.<br>
# Model reacts okay to smooth changes.<br>
# manages to follow upward,downward and stable trends.<br>
# And that makes a really good result.<br>

# %%
# Recurrent Neural Network



# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the training set
dataset_train = pd.read_csv('Google_Stock_Price_Train.csv')
training_set = dataset_train.iloc[:, 1:2].values

# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# Initialising the RNN
regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# Adding the output layer
regressor.add(Dense(units = 1))

# Compiling the RNN
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# Using TensorFlow backend.

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 1198/1198 [==============================] - 23s 19ms/step - loss: 0.0552
# Epoch 2/100
# 1198/1198 [==============================] - 17s 15ms/step - loss: 0.0071
# Epoch 3/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0057
# Epoch 4/100
# 1198/1198 [==============================] - 17s 15ms/step - loss: 0.0051
# Epoch 5/100
# 1198/1198 [==============================] - 18s 15ms/step - loss: 0.0048
# Epoch 6/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0050
# Epoch 7/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0057
# Epoch 8/100
# 1198/1198 [==============================] - 17s 15ms/step - loss: 0.0046
# Epoch 9/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0043
# Epoch 10/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0043
# Epoch 11/100
# 1198/1198 [==============================] - 17s 14ms/step - loss: 0.0044
# ...

# %%
# Part 3 - Making the predictions and visualising the results

# Getting the real stock price of 2017
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# Getting the predicted stock price of 2017
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
